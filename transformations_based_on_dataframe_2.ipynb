# %% [markdown]
# <a href="https://colab.research.google.com/github/kady05naik/PySpark/blob/main/transformations_based_on_dataframe_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Transformations on Data Frame 2

# %%
from pyspark.sql import SparkSession

# %%
spark=SparkSession.builder \
  .appName('myApp') \
  .getOrCreate()

# %%
data = [(1, "James", "Sales"),(2, "Michael", "Finance"),(3, "James", "Sales"),
         (4, "Maria", "HR"), (5, "Michael", "Finance"), (6, "Tom", "Sales"),
         (7, "Sara", "HR"), (8, "David", "Finance"),(9, "Mike", "Sales"),
         (10, "Emma", "HR")  ]

# %%
from pyspark.sql.types import *

# %%
schema=StructType([
    StructField('id',IntegerType(), True),
    StructField('name', StringType(), True),
    StructField('dept', StringType(), True)
])

# %%
df=spark.createDataFrame(data,schema)

# %%
df.show()
# Out:
# +---+-------+-------+
# | id|   name|   dept|
# +---+-------+-------+
# |  1|  James|  Sales|
# |  2|Michael|Finance|
# |  3|  James|  Sales|
# |  4|  Maria|     HR|
# |  5|Michael|Finance|
# |  6|    Tom|  Sales|
# |  7|   Sara|     HR|
# |  8|  David|Finance|
# |  9|   Mike|  Sales|
# | 10|   Emma|     HR|
# +---+-------+-------+
