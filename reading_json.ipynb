# %% [markdown]
# <a href="https://colab.research.google.com/github/kady05naik/PySpark/blob/gcolab/reading_json.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Reading .json file

# %%
from pyspark.sql import SparkSession

# %%
spark=SparkSession.builder.appName('myApp').getOrCreate()

# %%
df=spark.read \
  .option("multiline", 'True') \
  .json("/data.json")

# %% [markdown]
# ### Spark automatically infers nested structure.

# %%
df.printSchema()
# Out:
# root
#  |-- customer: struct (nullable = true)
#  |    |-- id: long (nullable = true)
#  |    |-- name: string (nullable = true)
#  |-- items: array (nullable = true)
#  |    |-- element: struct (containsNull = true)
#  |    |    |-- price: long (nullable = true)
#  |    |    |-- product: string (nullable = true)
#  |-- order_id: long (nullable = true)

# %%
df.show()
# Out:
# +---------+--------------------+--------+
# | customer|               items|order_id|
# +---------+--------------------+--------+
# |{1, John}|[{100, A}, {200, B}]|     101|
# | {2, Jia}|[{100, A}, {200, B}]|     102|
# +---------+--------------------+--------+

# %% [markdown]
# ## Using Explicit Schema

# %%
from pyspark.sql.types import *

# %%
schema=StructType([
    StructField ("order_id",IntegerType(),True),
    StructField ("customer", StructType([
        StructField("id", IntegerType(), True),
        StructField("name", StringType(), True)
    ])),
    StructField("items", ArrayType(
        StructType([
          StructField("product", StringType(), True),
          StructField("price", DoubleType(), True)
        ])
    ))
])

# %%
df2=spark.read \
  .option('multiline', True) \
  .schema(schema) \
  .json("/data.json")

# %%
df2.show(truncate=False)
# Out:
# +--------+---------+------------------------+
# |order_id|customer |items                   |
# +--------+---------+------------------------+
# |101     |{1, John}|[{A, 100.0}, {B, 200.0}]|
# |102     |{2, Jia} |[{A, 100.0}, {B, 200.0}]|
# +--------+---------+------------------------+

# %%
df.select('order_id','customer.id','customer.name','items.product','items.price').show()
# Out:
# +--------+---+----+-------+----------+
# |order_id| id|name|product|     price|
# +--------+---+----+-------+----------+
# |     101|  1|John| [A, B]|[100, 200]|
# |     102|  2| Jia| [A, B]|[100, 200]|
# +--------+---+----+-------+----------+

# %% [markdown]
# ### Nested .json flattening

# %%
from pyspark.sql.functions import explode

df_exploded = df.withColumn("item", explode("items"))

df_exploded.select(
    "order_id",
    "customer.id",
    "customer.name",
    "item.product",
    "item.price"
).show()
# Out:
# +--------+---+----+-------+-----+
# |order_id| id|name|product|price|
# +--------+---+----+-------+-----+
# |     101|  1|John|      A|  100|
# |     101|  1|John|      B|  200|
# |     102|  2| Jia|      A|  100|
# |     102|  2| Jia|      B|  200|
# +--------+---+----+-------+-----+
