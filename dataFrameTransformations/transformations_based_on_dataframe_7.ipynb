# %% [markdown]
# <a href="https://colab.research.google.com/github/kady05naik/PySpark/blob/main/dataFrameTransformations/transformations_based_on_dataframe_7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Transformations on Data Frame 7

# %%
from pyspark.sql import SparkSession
from pyspark.sql.functions import *
from pyspark.sql.types import *

# %%
spark=SparkSession.builder \
  .appName('myApp') \
  .getOrCreate()

# %%
data = [(1,'maheer','male','IT'),
       (2,'wafa','male','IT'),
       (3,'asi','female','HR'),
       (4,'annu','female','HR'),
       (5,'shakti','female','IT'),
       (6,'pradeep','male','HR'),
       (7,'sarfaraj','male','IT'),
       (8,'ayesha','female','IT')
       ]

# %%
schema=StructType([
    StructField('id',IntegerType(), True),
    StructField('name',StringType(), True),
    StructField('gender', StringType(), True),
    StructField('dept', StringType(), True)
])

# %%
df=spark.createDataFrame(data,schema)

# %% [markdown]
# ---

# %% [markdown]
# Do needful for below output
#
#
# ```
# +----+------+-----+
# |dept|gender|count|
# +----+------+-----+
# |  IT|  male|    3|
# |  HR|female|    2|
# |  HR|  male|    1|
# |  IT|female|    2|
# +----+------+-----+
#
# ```

# %%
df.groupBy('dept','gender') \
  .count() \
  .show()
# Out:
# +----+------+-----+
# |dept|gender|count|
# +----+------+-----+
# |  IT|  male|    3|
# |  HR|female|    2|
# |  HR|  male|    1|
# |  IT|female|    2|
# +----+------+-----+

# %% [markdown]
# ---

# %%
spark.stop()
